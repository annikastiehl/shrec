# %% [markdown]
# #### Preamble

# %%
# %matplotlib inline

import matplotlib.pyplot as plt
import numpy as np

import matplotlib.pyplot as plt
plt.rcParams.update(plt.rcParamsDefault)
# %matplotlib inline

# %% [markdown]
# # A forced dynamical system
#
# The Lorenz attractor forced by the Rossler attractor. The Lorenz response measurements have been filtered with random Gaussian kernels

# %%
X_measure = np.load("./benchmarks/data/lorenz_data.npy", allow_pickle=True)
y_driver = np.load("./benchmarks/data/lorenz_driver.npy", allow_pickle=True)

# %%
standardize_ts = lambda ts: (ts - np.mean(ts)) / np.std(ts)

plt.figure(figsize=(10, 12))
plt.plot(10 + standardize_ts(y_driver), linewidth=3, color='b')
# plt.title("True Driver")


for i in range(50):
    plt.plot(-i + standardize_ts(X_measure[:, i]), 'k', linewidth=1, alpha=0.5);

# remove frame and ticks
for spine in plt.gca().spines.values():
    spine.set_visible(False)
plt.gca().axis('off')
plt.title("Driving signal and response time series")
# Out:
# /tmp/ipykernel_41637/2985081164.py:1: RuntimeWarning: divide by zero encountered in divide
#   standardize_ts = lambda ts: (ts - np.mean(ts)) / np.std(ts)
# /tmp/ipykernel_41637/2985081164.py:1: RuntimeWarning: invalid value encountered in divide
#   standardize_ts = lambda ts: (ts - np.mean(ts)) / np.std(ts)
# Text(0.5, 1.0, 'Driving signal and response time series')

# %%
from shrec.models import RecurrenceManifold
model = RecurrenceManifold(random_state=0)
y_reconstructed = model.fit_predict(X_measure)

plt.figure()
plt.plot(y_driver)

plt.figure()
plt.plot(y_reconstructed)
# Out:
# /media/annika/Daten1/Promotion/18_Marseille/01_Code/shrec/shrec/models.py:302: UserWarning: 13 Constant time series detected. Skipping these datasets.
#   warnings.warn(f"{np.sum(sel_inds)} Constant time series detected. "

# %% [markdown]
# # Natal ECG
#
# The data is taken from the [NInFea database](https://physionet.org/content/ninfea/1.0.0/)

# %%
## View and plot data

X_measure = np.load("./benchmarks/data/ecg_data.npy", allow_pickle=True)
y_signal = np.load("./benchmarks/data/ecg_driver.npy", allow_pickle=True)

plt.figure(figsize=(10, 5))
plt.subplot(2, 1, 1)
plt.plot(X_measure)
plt.ylabel("Fetal ECG")

plt.subplot(2, 1, 2)
plt.plot(y_signal)
plt.ylabel("Maternal respiration")
# Out:
# Text(0, 0.5, 'Maternal respiration')

# %%
from shrec.models import RecurrenceManifold
from shrec.utils import standardize_ts

model = RecurrenceManifold(random_state=0)
driver_estimate = model.fit_predict(X_measure)

plt.figure()
plt.plot(standardize_ts(driver_estimate))
# plt.figure()
plt.plot(standardize_ts(y_signal))

# %% [markdown]
# # Fluid mixing

# %%
## View and plot data

X_measure = np.load("./benchmarks/data/fluid_data.npy", allow_pickle=True)
y_signal = np.load("./benchmarks/data/fluid_driver.npy", allow_pickle=True)

plt.figure(figsize=(10, 5))
plt.subplot(2, 1, 1)
plt.plot(X_measure)
plt.ylabel("Radial Velocity")

plt.subplot(2, 1, 2)
plt.plot(y_signal)
plt.ylabel("Flow control signal")
# Out:
# Text(0, 0.5, 'Flow control signal')

# %%
from shrec.models import RecurrenceManifold
from shrec.utils import standardize_ts

model = RecurrenceManifold(random_state=0)
driver_estimate = model.fit_predict(X_measure)

plt.plot(standardize_ts(driver_estimate))
plt.plot(standardize_ts(y_signal))

# %% [markdown]
# # Plankton Ecosystem
#
# Species abundances in two alpine Swiss lengths over a 40 year observation period. The data is from the [Swiss Federal Institute of Aquatic Science and Technology](https://opendata.eawag.ch/dataset/data-for-interacting-temperature-nutrients-and-zooplankton-grazing-control).

# %%
## View and plot data

X_measure = np.load("./benchmarks/data/eco_data.npy", allow_pickle=True)
y_signal = np.load("./benchmarks/data/eco_driver.npy", allow_pickle=True)

plt.figure(figsize=(10, 5))
plt.subplot(2, 1, 1)
plt.plot(X_measure)
plt.ylabel("Species abundance")

plt.subplot(2, 1, 2)
plt.plot(y_signal)
plt.ylabel("Water Temperature")
# Out:
# Text(0, 0.5, 'Water Temperature')

# %%
from shrec.models import RecurrenceManifold
from shrec.utils import standardize_ts

model = RecurrenceManifold(random_state=0, detrend=True)
driver_estimate = model.fit_predict(X_measure)

plt.figure()
plt.plot(standardize_ts(driver_estimate))
plt.plot(standardize_ts(y_signal))

# %% [markdown]
# # Monkey Motor Cortical
#
# A recording of neurons a monkey motor cortex, while the animal reaches for targets. The behavioral readout are x and y velocities of the reaching movement.

# %%
## View and plot data

X_measure = np.load("./benchmarks/data/monkey_data.npy", allow_pickle=True)
y_signal = np.load("./benchmarks/data/monkey_driver.npy", allow_pickle=True)

plt.figure(figsize=(10, 5))
plt.subplot(2, 1, 1)
plt.plot(X_measure)
plt.ylabel("Radial Velocity")

plt.subplot(2, 1, 2)
plt.plot(y_signal)
plt.ylabel("Flow control signal")
# Out:
# Text(0, 0.5, 'Flow control signal')

# %%
from shrec.models import RecurrenceManifold
from shrec.utils import standardize_ts

model = RecurrenceManifold(random_state=0)
driver_estimate = model.fit_predict(X_measure)

plt.plot(standardize_ts(driver_estimate))
plt.plot(standardize_ts(y_signal))

# %% [markdown]
# # Gene expression
#
#  Stochastic gene expression dynamics in a subset of the yeast metabolic gene regulatory network, in response to a simulated knockdown perturbation. The dataset is generated using the open-source [GeneNetWeaver software](https://gnw.sourceforge.net/)

# %%
## View and plot data

X_measure = np.load("./benchmarks/data/gene_data.npy", allow_pickle=True)
y_signal = np.load("./benchmarks/data/gene_driver.npy", allow_pickle=True)

plt.figure(figsize=(10, 5))
plt.subplot(2, 1, 1)
plt.plot(X_measure)
plt.ylabel("Radial Velocity")

plt.subplot(2, 1, 2)
plt.plot(y_signal)
plt.ylabel("Flow control signal")
# Out:
# Text(0, 0.5, 'Flow control signal')

# %%
from shrec.models import RecurrenceManifold
from shrec.utils import standardize_ts

model = RecurrenceManifold(random_state=0)
driver_estimate = model.fit_predict(X_measure)

plt.plot(-standardize_ts(driver_estimate))
plt.plot(standardize_ts(y_signal))

# %% [markdown]
# # Starting here the code for the EEG Data from Erlangen

# %%
import edfio
import numpy as np


def extract_eeg_data(filepath):
    X_eeg = edfio.read_edf(filepath)
    X_data = None

    for sig in X_eeg.labels:
        if not "p " in sig.lower():
            if X_data is None:
                X_data = X_eeg.get_signal(sig).data
            else:
                X_data = np.vstack((X_data, X_eeg.get_signal(sig).data))
    return X_data

# %%
# First read the data:
# Datapath: /media/annika/Daten1/Promotion/04_Daten/EEG-Daten Erlangen/EDF/130711BB_0012-export_Absc_4.edf
X_eeg = extract_eeg_data("/media/annika/Daten1/Promotion/04_Daten/EEG-Daten Erlangen/EDF/130711BB_0012-export_Absc_4.edf")

# %%
# Cut the signals as you want: 
# For the ABSC_4 data I used: 10-20 seconds (256 Hz -> 2560 samples)
start_time = 10  # in seconds
end_time = 20    # in seconds
sampling_rate = 256  # in Hz

X_eeg = X_eeg[:, start_time*sampling_rate:end_time*sampling_rate]

print(X_eeg.shape)
# Out:
# (25, 2560)

# %%
# Plot the EEG signals with an offset for better visibility
plt.figure(figsize=(15, 8))
for i in range(X_eeg.shape[0]):
    plt.plot(-i + standardize_ts(X_eeg[i, :]), 'k', linewidth=1, alpha=0.5);
plt.title("EEG Signals")
plt.xlabel("Time (samples)")
plt.ylabel("Channels (offset for visibility)")
# Out:
# Text(0, 0.5, 'Channels (offset for visibility)')

# %%
# Now lets start the shrec analysis:
from shrec.models import RecurrenceManifold
from shrec.utils import standardize_ts
model = RecurrenceManifold(random_state=0, detrend=True)

y_reconstructed = model.fit_predict(X_eeg.T)
print(y_reconstructed.shape)

plt.figure(figsize=(15, 8))
plt.plot(standardize_ts(y_reconstructed))
# Out:
# (2560,)

# %%
# Lets do some Frequency Comparison
from scipy.signal import welch
choose_channel = 6  # Choose which EEG channel to compare with
f, Pxx_den = welch(standardize_ts(y_reconstructed), sampling_rate, nperseg=1024)
f2, Pxx_den2 = welch(standardize_ts(X_eeg[choose_channel, :]), sampling_rate, nperseg=1024)
plt.figure(figsize=(10, 5))
plt.semilogy(f, Pxx_den, label='Reconstructed Driver')
plt.semilogy(f2, Pxx_den2, label=f'Original EEG Channel {choose_channel}')
plt.xlabel('frequency [Hz]')
plt.ylabel('PSD [V**2/Hz]')
plt.legend()
plt.title('Power Spectral Density Comparison')
# Out:
# Text(0.5, 1.0, 'Power Spectral Density Comparison')

# %% [markdown]
# # Appendix

# %%
# model.adjacency_matrix
# https://dyeun.wordpress.ncsu.edu/files/2022/08/Sigmetrics20-FV-1.pdf

## Simulate a diffusion process on a similarity graph

n_walkers = 500
A = model.adjacency_matrix.copy()

# Normalize A to make it a stochastic matrix
row_sums = A.sum(axis=1)
stochastic_matrix = A / row_sums[:, np.newaxis]

# Initialize
num_nodes = stochastic_matrix.shape[0]
num_steps = 2000 # Define the number of steps in the random walk
walker_distribution = np.full(num_nodes, 1/num_nodes) # Uniform distribution

# Simulate the random walk
for _ in range(num_steps):
    walker_distribution = stochastic_matrix.T @ walker_distribution

# The walker_distribution now represents the steady state distribution
# print(walker_distribution)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[31], line 7
#       1 # model.adjacency_matrix
#       2 # https://dyeun.wordpress.ncsu.edu/files/2022/08/Sigmetrics20-FV-1.pdf
#       3
#       4 ## Simulate a diffusion process on a similarity graph
#       6 n_walkers = 500
# ----> 7 A = model.adjacency_matrix.copy()
#       9 # Normalize A to make it a stochastic matrix
#      10 row_sums = A.sum(axis=1)
#
# AttributeError: 'RecurrenceManifold' object has no attribute 'adjacency_matrix'

# %%
import scipy.linalg
eigvals, eigvecs = scipy.linalg.eigh(
    model.adjacency_matrix, 
    subset_by_index=[model.adjacency_matrix.shape[0]-2, model.adjacency_matrix.shape[0]-1]
)

plt.figure()
plt.plot(-standardize_ts(eigvecs[:, -1]))
plt.plot(standardize_ts(walker_distribution))

from sklearn.manifold import SpectralEmbedding

embedder = SpectralEmbedding(
    n_components=1, 
    random_state=0, 
    affinity='precomputed'
)
driver_estimate = embedder.fit_transform(model.adjacency_matrix).squeeze()

plt.figure()
plt.plot(-standardize_ts(eigvecs[:, -2]))
plt.plot(standardize_ts(driver_estimate))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[32], line 3
#       1 import scipy.linalg
#       2 eigvals, eigvecs = scipy.linalg.eigh(
# ----> 3     model.adjacency_matrix,
#       4     subset_by_index=[model.adjacency_matrix.shape[0]-2, model.adjacency_matrix.shape[0]-1]
#       5 )
#       7 plt.figure()
#       8 plt.plot(-standardize_ts(eigvecs[:, -1]))
#
# AttributeError: 'RecurrenceManifold' object has no attribute 'adjacency_matrix'

# %% [markdown]
# # Development

# %%
## The distance matrix encodes a geometry on a given slice through a high dimensional space
## We have K slices through this space
## Can we infer the true geometry of the space from the distance matrices?

## Think of each observed time series as a random projection of the high dimensional space

# %%
from scipy.spatial import KDTree

prep = RecurrenceManifold()

X = prep._preprocess(X_measure.copy())
X = prep._make_embedding(X)

all_kd = [KDTree(Xs) for Xs in X]

# for each node, find the k nearest neighbors
k = 10
for i in range(X[0].shape[0]):
    for j in range(len(X)):
        # get the index of the k nearest neighbors of index i in graph j
        dists, idx = all_kd[j].query(X[j][i, :].reshape(1, -1), k=k)

        

    

# X.shape

# two nodes are similar if they share many neighbors
# Out:
# (24, 3000, 3)

# %%
model = RecurrenceManifold(random_state=0, store_adjacency_matrix=True, return_matrices=True)
model.fit(X_measure)

amat = np.mean(model.matrices, axis=0)
import scipy.linalg
eigvals, eigvecs = scipy.linalg.eigh(
    amat, 
    subset_by_index=[amat.shape[0]-2, amat.shape[0]-1]
)
plt.plot(-standardize_ts(eigvecs[:, -2]))
plt.plot(standardize_ts(y_signal))

# %%
func = lambda sig: sum(np.exp(-relu(dists - 0.1) / sig)) - log2(k)
jac = lambda sig: sum(np.exp(-relu(dists - 0.1) / sig) * relu(dists - 0.1)) / sig**2

print((func(1.4) - func(1.399))/ 0.001)
print(jac(1.4))
# Out:
# [ 6.70902035 11.18376399 14.97128163 18.71164257 21.45254545 23.96351835
#  26.61358814 28.91932315 31.18983295 33.33070195 35.49407983 37.68995219
#  39.82066187 41.94260377 43.95851446 46.04602515 48.11442889 50.1790842
#  52.30621693]
# [ 6.70457111 11.1764028  14.96148587 18.69950821 21.43869465 23.94807911
#  26.59648864 28.90074721 31.16980918 33.30930022 35.47128078 37.66573804
#  39.79506694 41.9156309  43.93022235 46.01637635 48.08342164 50.1467357
#  52.27248227]

# %%
# prep = RecurrenceManifold()
# X = prep._preprocess(X_measure.copy())
# X = prep._make_embedding(X)

from shrec.models import RecurrenceManifold



prep = RecurrenceManifold()

X = prep._preprocess(X_measure.copy())
X = prep._make_embedding(X)







    


all_wmat = []
k = 20
nb, nt, nd = X.shape
# wmat = np.zeros((nt, nt))
## coo_matrix
from scipy.sparse import coo_matrix



for ind, X0 in enumerate(X):
    print(ind, "/", len(X), flush=True)
    # wmat =  dataset_to_simplex(X0, k=k)
    # wmat += dataset_to_simplex(X0, k=k) / nb
    # all_wmat.append(wmat)

    result, sigmas, rhos, dists = fuzzy_simplicial_set(X0, k, 0, 'euclidean', return_dists=True)
    wmat += result / nb
    all_wmat.append(wmat)


# all_wmat = np.array(all_wmat)

# bd = dataset_to_connectivity(X)


    ## Compute the scaling parameter \sigma_i for each node by solving the following equation
    ## np.log2(k) = sum_{j=1}^k np.exp(-np.max(0, d(x_i, x_j) - rhoi} / sigma_i)
    ## where d(x_i, x_j) is the distance between nodes i and j
    ## and rhoi is the distance to the kth nearest neighbor of node i
    ## and sigma_i is the scaling parameter for node i
    ## and k is the number of nearest neighbors
# Out:
# 0 / 96
# 1 / 96
# 2 / 96
# 3 / 96
# 4 / 96
# 5 / 96
# 6 / 96
# 7 / 96
# 8 / 96
# 9 / 96
# 10 / 96
# 11 / 96
# 12 / 96
# 13 / 96
# 14 / 96
# 15 / 96
# 16 / 96
# 17 / 96
# 18 / 96
# 19 / 96
# 20 / 96
# 21 / 96
# 22 / 96
# 23 / 96
# 24 / 96
# 25 / 96
# 26 / 96
# 27 / 96
# 28 / 96
# 29 / 96
# 30 / 96
# 31 / 96
# 32 / 96
# 33 / 96
# 34 / 96
# 35 / 96
# 36 / 96
# 37 / 96
# 38 / 96
# 39 / 96
# 40 / 96
# 41 / 96
# 42 / 96
# 43 / 96
# 44 / 96
# 45 / 96
# 46 / 96
# 47 / 96
# 48 / 96
# 49 / 96
# 50 / 96
# 51 / 96
# 52 / 96
# 53 / 96
# 54 / 96
# 55 / 96
# 56 / 96
# 57 / 96
# 58 / 96
# 59 / 96
# 60 / 96
# 61 / 96
# 62 / 96
# 63 / 96
# 64 / 96
# 65 / 96
# 66 / 96
# 67 / 96
# 68 / 96
# 69 / 96
# 70 / 96
# 71 / 96
# 72 / 96
# 73 / 96
# 74 / 96
# 75 / 96
# 76 / 96
# 77 / 96
# 78 / 96
# 79 / 96
# 80 / 96
# 81 / 96
# 82 / 96
# 83 / 96
# 84 / 96
# 85 / 96
# 86 / 96
# 87 / 96
# 88 / 96
# 89 / 96
# 90 / 96
# 91 / 96
# 92 / 96
# 93 / 96
# 94 / 96
# 95 / 96

# %%
dmat = cdist(X0, X0)
for i in range(X0.shape[0]):
    # get the index of the k nearest neighbors of index i in graph j, excluding the node itself
    dists, idx = KDTree(X0).query(X0[i, :].reshape(1, -1), k=k)
    dists, idx = dists[0][1:], idx[0][1:]
    rhoi = np.min(dists)
    # sigma_i = compute_sigma_i(dists, k, rhoi)
    func = lambda sig: sum(np.exp(-relu(dists - rhoi) / sig)) - np.log2(k)
    sigma_i = fsolve(func, rhoi)[0]
    dmat[i] = np.exp(-relu(dmat[i] - rhoi) / sigma_i)
    break
wmat = dmat + dmat.T - dmat * dmat.T

# %%
# get the index of the k nearest neighbors of all datapoints in X0
dists, idx = KDTree(X0).query(X0, k=k)
dists, idx = dists[:, 1:], idx[:, 1:] # exclude the node itself
rhoi = np.min(dists, axis=1, keepdims=True)
func = lambda sig: np.sum(np.exp(-relu(dists - rhoi) / sig), axis=1, keepdims=True) - np.log2(k)
# func = lambda sig: sig - np.log2(k)
sigma_i = fsolve(func, rhoi)[0]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[75], line 7
#       5 func = lambda sig: np.sum(np.exp(-relu(dists - rhoi) / sig), axis=1, keepdims=True) - np.log2(k)
#       6 # func = lambda sig: sig - np.log2(k)
# ----> 7 sigma_i = fsolve(func, rhoi)[0]
#
# File ~/micromamba/envs/cphy/lib/python3.11/site-packages/scipy/optimize/_minpack_py.py:162, in fsolve(func, x0, args, fprime, full_output, col_deriv, xtol, maxfev, band, epsfcn, factor, diag)
#      50 """
#      51 Find the roots of a function.
#      52
#    (...)
#     152
#     153 """
#     154 options = {'col_deriv': col_deriv,
#     155            'xtol': xtol,
#     156            'maxfev': maxfev,
#    (...)
#     159            'factor': factor,
#     160            'diag': diag}
# --> 162 res = _root_hybr(func, x0, args, jac=fprime, **options)
#     163 if full_output:
#     164     x = res['x']
#
# ...

# %%
# model.adjacency_matrix

from umap import UMAP

from scipy.spatial import KDTree


prep = RecurrenceManifold()

X = prep._preprocess(X_measure.copy())
X = prep._make_embedding(X)

n_walkers = 20000
tau = 0.1


n_series, n_tpts, n_dim = X.shape


## Build KD trees for each time series
all_kd = [KDTree(Xs) for Xs in X]

## Initial positions
walkers = np.random.choice(n_tpts, n_walkers, replace=True)
# walkers = np.arange(n_walkers).astype(int)
# all_pos = X[0, walkers, :]

for _ in range(200):
    ## Pick a random time series

    ts_ind = np.random.choice(n_series)
    timepoint_ind = np.random.choice(n_tpts)

    kd = all_kd[ts_ind]
    dists, inds = kd.query(X[ts_ind, walkers], k=2)
    dists, inds = dists[..., -1], inds[..., -1] # distance to nearest neighbor

    p_jump = np.exp(-dists / tau)
    # p_jump /= np.sum(p_jump)
    
    ## does jump
    does_jump = np.random.random(n_walkers) < p_jump

    ## update positions
    walkers[does_jump] = inds[does_jump]


    # dists, _ = kd.query(X_measure, k=2)
    # dists = dists[:, 1:] # distance to k-nearest neighbors excluding self

    ## aggregate and prune trees

## Pick a random time series and neighbor
# kval = 5

    # dists, _ = kd.query(X, k=kval)
    # dists = dists[:, 1:] # distance to k-nearest neighbors excluding self

    ## aggregate and prune trees




# embedder = UMAP(n_components=1, metric="precomputed")
# traj = embedder.fit_transform(model.adjacency_matrix)
